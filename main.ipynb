# %%
#imports

# %%
#initialise and connect to database

# %%
def mark_presence():
    pass

# %%
def mark_absence():
    pass

# %%
def admin_panel():
    pass

# %%
def convert_to_pdf():
    pass

# %%
def admin_login():
    pass
